# %%
import pandas as pd

# %%
expectimaxStatistic = pd.read_csv("win_loss_expectimax.csv")

# %%
expectimaxStatistic
# Out:
#                        id  win(0-no, 1-yes)  expectimax_score  opponent_score  \
# 0       human_expectimax1                 0                 9              12
# 1       human_expectimax2                 0                 7              12
# 2       human_expectimax3                 1                12               8
# 3   minimax1_expectimax1                  0                 2              11
# 4   minimax1_expectimax2                  0                 1              12
# 5   minimax1_expectimax3                  0                 1              11
# 6    minimax2_expectimax1                 0                 1              12
# 7   minimax2_expectimax2                  0                 0              11
# 8    minimax2_expectimax3                 0                 1              12
# 9    minimax3_expectimax1                 0                 1              12
# 10  minimax3_expectimax2                  0                 1              12
# 11  minimax3_expectimax3                  0                 1              10
#
#     draws  duration(sec)
# 0      90          4.706
# 1      48          4.962
# 2      51          4.199
# 3      39          2.065
# 4      31          2.105
# 5      37          2.812
# 6      35          1.597
# 7      43          2.504
# 8      35          2.267
# 9      41          2.332
# 10     41          2.959
# 11     37          3.119

# %%
minimaxStatistic = pd.read_csv("win_loss_minimax.csv")

# %%
minimaxStatistic
# Out:
#                       id  win(0-no, 1-yes)  minimax_socre  opponent_score  \
# 0         human_minimax1                 1             12               9
# 1         human_minimax2                 1             12               6
# 2         human_minimax3                 1             10               7
# 3   minimax1_expectimax1                 1             11               2
# 4   minimax1_expectimax2                 1             12               1
# 5   minimax1_expectimax3                 1             11               1
# 6   minimax2_expectimax1                 1             12               1
# 7   minimax2_expectimax2                 1             11               0
# 8   minimax2_expectimax3                 1             12               1
# 9   minimax3_expectimax1                 1             12               1
# 10  minimax3_expectimax2                 1             12               1
# 11  minimax3_expectimax3                 1             10               1
#
#     draws  duration(sec)
# 0      79          3.021
# 1     101          5.201
# 2      87          6.864
# 3      39          2.395
# 4      31          1.865
# 5      37          2.835
# 6      35          3.089
# 7      43          3.110
# 8      35          3.179
# 9      41          4.089
# 10     41          3.811
# 11     37          4.254

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
#Histogram za broj na pobedi
plt.figure(figsize=(8,5))
sns.barplot(x=['Expectimax Wins', 'Minimax Wins'], y=[expectimaxStatistic['win(0-no, 1-yes)'].sum(), minimaxStatistic['win(0-no, 1-yes)'].sum()])
plt.ylabel("Број на победи")
plt.title("Број на победи: Minimax vs Expectimax")

plt.show()

# %%
# Bar chart za sporedba na postignati poeni na exceptimax vo odnos na protivnicite
plt.figure(figsize=(7, 4))
sns.barplot(x='id', y='expectimax_score', data=expectimaxStatistic, color='red', label='Expectimax Score')
sns.barplot(x='id', y='opponent_score', data=expectimaxStatistic, color='blue', alpha=0.6, label='Opponent Score')
plt.xticks(rotation=90)
plt.legend()
plt.title("Споредба на поени за Expectimax")
plt.show()

# %%
# Bar chart za sporedba na postignati poeni na minimax vo odnos na protivnicite
plt.figure(figsize=(7,4))
sns.barplot(x='id', y='minimax_socre', data=minimaxStatistic, color='red', label='Minimax Score')
sns.barplot(x='id', y='opponent_score', data=minimaxStatistic, color='blue', alpha=0.6, label='Opponent Score')
plt.xticks(rotation=90)
plt.legend()
plt.title("Споредба на поени за Minimax")
plt.show()

# %%
#Line plot za vremetraenje na partiite
plt.figure(figsize=(7, 4))
sns.lineplot(x='id', y='duration(sec)', data=expectimaxStatistic, marker='o', label='Expectimax Duration')
plt.xticks(rotation=90)
plt.title("Времетраење на Expectimax")
plt.ylabel("Време (секунди)")
plt.legend()
plt.show()

# %%
#Line plot za vremetraenje na partiite
plt.figure(figsize=(7, 4))
sns.lineplot(x='id', y='duration(sec)', data=minimaxStatistic, marker='s', label='Minimax Duration')
plt.xticks(rotation=90)
plt.title("Времетраење на Minimax")
plt.ylabel("Време (секунди)")
plt.legend()
plt.show()

# %%
averageDurationMinimax = minimaxStatistic['duration(sec)'].mean()
averageDurationExpectimax = expectimaxStatistic['duration(sec)'].mean()
print("Prosecnoto vreme na minimax e: ", averageDurationMinimax)
print("Prosecnoto vreme na expectimax e: ", averageDurationExpectimax)
# Out:
# Prosecnoto vreme na minimax e:  3.64275
# Prosecnoto vreme na expectimax e:  2.968916666666667

# %%
data_expectimax = {
    "id": ["human_expectimax1", "human_expectimax2", "human_expectimax3",
           "minimax1_expectimax1", "minimax1_expectimax2", "minimax1_expectimax3",
           "minimax2_expectimax1", "minimax2_expectimax2", "minimax2_expectimax3",
           "minimax3_expectimax1", "minimax3_expectimax2", "minimax3_expectimax3"],
    "expectimax_score": [9, 7, 12, 2, 1, 1, 1, 0, 1, 1, 1, 1]
}

# Податоци за Minimax
data_minimax = {
    "id": ["human_minimax1", "human_minimax2", "human_minimax3",
           "minimax1_expectimax1", "minimax1_expectimax2", "minimax1_expectimax3",
           "minimax2_expectimax1", "minimax2_expectimax2", "minimax2_expectimax3",
           "minimax3_expectimax1", "minimax3_expectimax2", "minimax3_expectimax3"],
    "minimax_score": [12, 12, 10, 11, 12, 11, 12, 11, 12, 12, 12, 10]
}

df_expectimax = pd.DataFrame(data_expectimax)
df_minimax = pd.DataFrame(data_minimax)

# %%
df_expectimax["expectimax_heuristic"] = df_expectimax["id"].str.extract(r'expectimax(\d+)').astype(int)
df_minimax["minimax_heuristic"] = df_minimax["id"].str.extract(r'minimax(\d+)').astype(int)

# %%
df_expectimax
# Out:
#                       id  expectimax_score  expectimax_heuristic
# 0      human_expectimax1                 9                     1
# 1      human_expectimax2                 7                     2
# 2      human_expectimax3                12                     3
# 3   minimax1_expectimax1                 2                     1
# 4   minimax1_expectimax2                 1                     2
# 5   minimax1_expectimax3                 1                     3
# 6   minimax2_expectimax1                 1                     1
# 7   minimax2_expectimax2                 0                     2
# 8   minimax2_expectimax3                 1                     3
# 9   minimax3_expectimax1                 1                     1
# 10  minimax3_expectimax2                 1                     2
# 11  minimax3_expectimax3                 1                     3

# %%
scores_by_expectimax_heuristic = df_expectimax.groupby("expectimax_heuristic")["expectimax_score"].sum()
scores_by_minimax_heuristic = df_minimax.groupby("minimax_heuristic")["minimax_score"].sum()

# %%
scores_by_minimax_heuristic
# Out:
# minimax_heuristic
# 1    46
# 2    47
# 3    44
# Name: minimax_score, dtype: int64

# %%
scores_by_expectimax_heuristic
# Out:
# expectimax_heuristic
# 1    13
# 2     9
# 3    15
# Name: expectimax_score, dtype: int64

# %%
plt.figure(figsize=(7, 4))
plt.bar(scores_by_expectimax_heuristic.index - 0.2, scores_by_expectimax_heuristic.values, width=0.4, label="Expectimax")
plt.bar(scores_by_minimax_heuristic.index + 0.2, scores_by_minimax_heuristic.values, width=0.4, label="Minimax")

plt.xlabel("Хевристика број")
plt.ylabel("Вкупен скор")
plt.xticks(range(1, int(max(scores_by_expectimax_heuristic.index.max(), scores_by_minimax_heuristic.index.max())) + 1))
plt.legend()
plt.title("Успешност на хевристиките во Minimax vs Expectimax (според скор)")
plt.show()

# %%
data_expectimax = {
    "id": ["human_expectimax1", "human_expectimax2", "human_expectimax3",
           "minimax1_expectimax1", "minimax1_expectimax2", "minimax1_expectimax3",
           "minimax2_expectimax1", "minimax2_expectimax2", "minimax2_expectimax3",
           "minimax3_expectimax1", "minimax3_expectimax2", "minimax3_expectimax3"],
    "opponent_score": [12, 12, 8, 11, 12, 11, 12, 11, 12, 12, 12, 10]
}

# Податоци за Minimax
data_minimax = {
    "id": ["human_minimax1", "human_minimax2", "human_minimax3",
           "minimax1_expectimax1", "minimax1_expectimax2", "minimax1_expectimax3",
           "minimax2_expectimax1", "minimax2_expectimax2", "minimax2_expectimax3",
           "minimax3_expectimax1", "minimax3_expectimax2", "minimax3_expectimax3"],
    "opponent_score": [9, 6, 7, 2, 1, 1, 1, 0, 1, 1, 1, 1]
}

df_expectimax = pd.DataFrame(data_expectimax)
df_minimax = pd.DataFrame(data_minimax)

df_expectimax["expectimax_heuristic"] = df_expectimax["id"].str.extract(r'expectimax(\d+)').astype(int)
df_minimax["minimax_heuristic"] = df_minimax["id"].str.extract(r'minimax(\d+)').astype(int)

scores_by_expectimax_heuristic = df_expectimax.groupby("expectimax_heuristic")["opponent_score"].sum()
scores_by_minimax_heuristic = df_minimax.groupby("minimax_heuristic")["opponent_score"].sum()

plt.figure(figsize=(7, 4))
plt.bar(scores_by_expectimax_heuristic.index - 0.2, scores_by_expectimax_heuristic.values, width=0.4, label="Expectimax_opponent")
plt.bar(scores_by_minimax_heuristic.index + 0.2, scores_by_minimax_heuristic.values, width=0.4, label="Minimax_opponent")

plt.xlabel("Хевристика број")
plt.ylabel("Вкупен скор")
plt.xticks(range(1, int(max(scores_by_expectimax_heuristic.index.max(), scores_by_minimax_heuristic.index.max())) + 1))
plt.legend()
plt.title("Успешност на противниците кои се бореле против хевристиките во Minimax vs Expectimax (според скор)")
plt.show()

# %%
expectimaxStatistic["expectimax_heuristic"] = expectimaxStatistic["id"].str.extract(r'expectimax(\d+)').astype(int)
minimaxStatistic["minimax_heuristic"] = minimaxStatistic["id"].str.extract(r'minimax(\d+)').astype(int)
minimaxStatistic
# Out:
#                       id  win(0-no, 1-yes)  minimax_socre  opponent_score  \
# 0         human_minimax1                 1             12               9
# 1         human_minimax2                 1             12               6
# 2         human_minimax3                 1             10               7
# 3   minimax1_expectimax1                 1             11               2
# 4   minimax1_expectimax2                 1             12               1
# 5   minimax1_expectimax3                 1             11               1
# 6   minimax2_expectimax1                 1             12               1
# 7   minimax2_expectimax2                 1             11               0
# 8   minimax2_expectimax3                 1             12               1
# 9   minimax3_expectimax1                 1             12               1
# 10  minimax3_expectimax2                 1             12               1
# 11  minimax3_expectimax3                 1             10               1
#
#     draws  duration(sec)  minimax_heuristic
# 0      79          3.021                  1
# 1     101          5.201                  2
# 2      87          6.864                  3
# 3      39          2.395                  1
# 4      31          1.865                  1
# 5      37          2.835                  1
# 6      35          3.089                  2
# 7      43          3.110                  2
# 8      35          3.179                  2
# 9      41          4.089                  3
# 10     41          3.811                  3
# 11     37          4.254                  3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.pairplot(expectimaxStatistic, height=1.3)



plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.pairplot(minimaxStatistic, height=1.3)



plt.show()
